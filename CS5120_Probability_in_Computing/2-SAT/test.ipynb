# %%
import random

# %%
class two_SAT:

    def __init__(self , num_clauses , num_variables , clause_list):
        self.num_clauses = num_clauses
        self.num_variables = num_variables
        
        self.clauses = []
        self.negations = []

        for clause in clause_list:
            c = []
            n = []
            for literal in clause:
                c.append(abs(literal))
                n.append(literal > 0)

            self.clauses.append(c)
            self.negations.append(n)

        self.assignment = [True] * self.num_variables


    def is_satisfied_clause(self , clause_number):
        clause = self.clauses[clause_number]
        negation = self.negations[clause_number]

        for literal_idx , literal in enumerate(clause):
            # if the assignment is equal to the negation bool,
            # the literal contributes a True
            if self.assignment[literal - 1] == negation[literal_idx]:
                return True
        return False
    
    def update (self , clause_number):
        clause = self.clauses[clause_number]

        to_update_index = random.randint(0 , len(clause) - 1)
        to_update_literal = clause[to_update_index]

        self.assignment[to_update_literal - 1] = not self.assignment[to_update_literal - 1]

    def convert_to_string(self):

        assignment_string = ""

        for a in self.assignment:
            assignment_string += '1' if a else '0'

        return assignment_string

    def find_satisfying_assignment(self):
        
        while 1:    # since input is guaranteed to be satisfiable
            found_false_clause = False
            for idx , clause in enumerate(self.clauses):
                if not self.is_satisfied_clause(idx):
                    self.update(idx)
                    found_false_clause = True
                    break
            
            if not found_false_clause:
                return self.convert_to_string()

        return self.convert_to_string()

# %%
file_name = "2-SAT-input5.txt"

clause_list = []

with open(file_name) as f:
    for idx , line in enumerate(f.readlines()):
        if idx == 0:
            num_variables = int(line.strip('\n'))
        elif idx == 1: 
            num_clauses = int(line.strip('\n'))
        else:
            clause_list.append([int(x) for x in line.strip('\n').split(',')])
            

two_sat = two_SAT(num_clauses , num_variables , clause_list)
two_sat.find_satisfying_assignment()
# Out:
# '01111111010110101100011111011111111110011111001011101111100111000011101011111011'

# %%
with open("output.txt" , 'r') as f:
    assignment = f.readlines()[0]

assignment
# Out:
# '11111111000110100100011111111111111110101101000011100111100011100111100011111111'

# %%
assignment_vals = [True if assignment[i] == '1' else False for i in range(len(assignment))]
assignment_vals
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
clauses = []
negations = []

for clause in clause_list:
    c = []
    n = []
    for literal in clause:
        c.append(abs(literal))
        n.append(literal > 0)

    clauses.append(c)
    negations.append(n)

# %%
for c_idx , clause in enumerate(clauses):
    for l_idx , literal in enumerate(clause):
        if assignment_vals[literal - 1] == negations[c_idx][l_idx]:
            print(clause_list[c_idx] , assignment_vals[clause[0]-1] , assignment_vals[clause[1]-1]) 
            break
    else:
        print(clause , negations[c_idx])
        print(sat_assignment)
        print("Not satisfied")
# Out:
# [-72, 28] False True
# [35, 26] True True
# [16, 3] False True
# [-44, -14] True False
# [50, -62] True True
# [39, 34] True True
# [47, -10] False False
# [63, 53] True False
# [-58, -7] False True
# [-38, -1] False True
# [30, 2] True True
# [36, 34] True True
# [-37, -11] True False
# [27, 32] True True
# [-72, -22] False True
# [5, -22] True True
# [75, 55] True True
# [-21, 7] False True
# [49, -2] True True
# [68, -47] True False
# [-11, -71] False False
# [-72, -79] False True
# [-28, 22] True True
# [-45, 8] False True
# [-47, -39] False True
# [-58, -12] False True
# [-20, -80] False True
# [-37, -45] True False
# [-62, 29] True True
# [-56, -65] True False
# [-64, -60] False False
# [-66, -48] True False
# [40, -17] False False
# [-49, -21] True False
# [-64, 32] False True
# [76, -55] True True
# [45, 4] False True
# [54, -3] True True
# [-7, 56] True True
# [42, 48] True False
# [-76, -58] True False
# [-57, 15] True True
# [76, -1] True True
# [-74, 67] True True
# [-64, -4] False True
# [-16, 15] False True
# [13, 33] True True
# [-9, -36] False True
# [50, -13] True True
# [9, -19] False False
# [23, -43] True False
# [-52, -60] False False
# [-65, -43] False False
# [-38, 41] False True
# [-25, -58] True False
# [-1, -17] True False
# [-59, 49] False True
# [-57, -16] True False
# [51, -21] True False
# [-78, -47] True False
# [-53, -63] False True
# [50, -74] True True
# [45, 68] False True
# [-8, 41] True True
# [67, 33] True True
# [-14, -66] False True
# [-48, 63] False True
# [14, 41] False True
# [9, 18] False True
# [67, -77] True True
# [67, -73] True True
# [-55, 13] True True
# [37, 5] True True
# [19, -70] False False
# [46, 15] False True
# [-54, -45] True False
# [12, 44] True True
# [34, 1] True True
# [63, 32] True True
# [4, -36] True True
# [36, -47] True False
# [68, -53] True False
# [56, -51] True True
# [53, -47] False False
# [-40, 37] False True
# [37, 47] True False
# [-45, 28] False True
# [63, 56] True True
# [23, 29] True True
# [-68, 75] True True
# [7, 50] True True
# [15, -42] True True
# [45, -59] False False
# [-9, -45] False False
# [-14, 2] False True
# [-31, 75] True True
# [78, -9] True False
# [-58, -21] False False
# [7, 17] True False
# [-52, -39] False True
# [49, -23] True True
# [-73, 30] True True
# [-10, -27] False True
# [62, -75] True True
# [65, 4] False True
# [-53, 76] False True
# [54, 27] True True
# [76, 31] True True
# [62, -14] True False
# [-70, 34] False True
# [41, -68] True True
# [-16, -1] False True
# [67, -14] True False
# [24, -44] True True
# [-58, 36] False True
# [-19, -14] False False
# [-48, 27] False True
# [34, 45] True False
# [-14, -20] False False
# [-19, -45] False False
# [-26, 36] True True
# [70, 50] False True
# [-80, -16] True False
# [67, -43] True False
# [-49, 79] True True
# [61, -13] True True
# [10, 33] False True
# [79, -61] True True
# [-57, 30] True True
# [-8, -21] True False
# [-71, -63] False True
# [-65, -74] False True
# [-46, -50] False True
# [23, 53] True False
# [-52, 66] False True
# [56, 68] True True
# [18, 52] True False
# [8, -5] True True
# [-72, 24] False True
# [44, 7] True True
# [32, 72] True False
# [-65, 16] False False
# [38, 68] False True
# [-47, -66] False True
# [-40, 12] False True
# [-65, -45] False False
# [-38, -57] False True
# [-38, 46] False False
# [7, -44] True True
# [11, -45] False False
